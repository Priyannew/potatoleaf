# %% [markdown]
# # Objective
# **- To classify the given leaf image as healthy, late blight or early blight**<br>
# **- Multiclass classification problem**<br>

# %% [markdown]
# # Data
# **-The dataset is originally collected from
# [kaggle.com](https://www.kaggle.com/arjuntejaswi/plant-village)**<br>
# **- A subset of the original data is created which includes only the diseases of potato plants**<br>
# **- Dataset used in this project -
# [click here!](https://www.kaggle.com/ashokkumarpalivela/potato-diseases)**
#
# #### Folder structure
# - data
#     - Late Blight
#         - img1.png
#         - img2.png
#         - ...
#     - Early Blight
#         - img1.png
#         - img2.png
#         - ...
#     - Healthy
#         - img1.png
#         - img2.png
#         - ...

# %% [markdown]
# # Dependencies

# %%
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array

print(tf.__version__)
############ settings ############
data_dir = r"data"

batch_size = 32
img_height = 128
img_width = 128
# Out:
# WARNING:tensorflow:From C:\Users\Home\AppData\Roaming\Python\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %% [markdown]
# # Data preprocessing
#
# **- Loading and splitting data<br>**
# **- Train:80% and Validation:20%**

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,

    validation_split=0.2,

    subset="training",

    seed=123,

    image_size=(img_height, img_width),

    batch_size=batch_size)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,

    validation_split=0.2,

    subset="validation",

    seed=123,

    image_size=(img_height, img_width),

    batch_size=batch_size)
# Out:
# Found 2152 files belonging to 3 classes.
# Using 1722 files for training.
# Found 2152 files belonging to 3 classes.
# Using 430 files for validation.

# %% [markdown]
# # EDA

# %%
def plot_distribution(y, title):
    a = Counter(y)
    y = ['Early_blight', 'Healthy', 'Late_blight']

    x = [a[i] for i in range(3)]
    plt.figure(figsize=(8, 3))
    plt.barh(y, x, color='blue')
    plt.title(title)
    return plt.show()


y_train = np.concatenate([y for x, y in train_ds], axis=0)
y_val = np.concatenate([y for x, y in val_ds], axis=0)

plot_distribution(y_train, title="Train images")
plot_distribution(y_val, title="Validation images")

# %%
# Target distribution

y_train = np.concatenate([y for x, y in train_ds], axis=0)
y_val = np.concatenate([y for x, y in val_ds], axis=0)

plot_distribution(y_train, title="Train images")
plot_distribution(y_val, title="Validation images")

# %%
# Sample images
class_names = train_ds.class_names

for class_name in class_names:
    imgs = os.listdir(os.path.join(data_dir, class_name))[:3]
    plt.figure(figsize=(10, 10))
    for i, img in enumerate(imgs):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(plt.imread(os.path.join(data_dir, class_name, img)))
        plt.title(class_name)
        plt.axis('off')

# %% [markdown]
# # Model Training

# %%
# Configure the dataset for performance

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Model architecture

num_classes = 3

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(img_height, img_width, 3)),
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),

    tf.keras.layers.Conv2D(16, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(64, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(num_classes, activation='softmax')

])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                                      min_delta=0.0001,
                                                      patience=5)

history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=20,
                    callbacks=[earlystop_callback])
# Out:
# Epoch 1/20
# 54/54 [==============================] - 29s 511ms/step - loss: 0.7728 - accuracy: 0.6440 - val_loss: 0.4142 - val_accuracy: 0.8186
# Epoch 2/20
# 54/54 [==============================] - 24s 448ms/step - loss: 0.3917 - accuracy: 0.8444 - val_loss: 0.3129 - val_accuracy: 0.8535
# Epoch 3/20
# 54/54 [==============================] - 25s 468ms/step - loss: 0.2940 - accuracy: 0.8879 - val_loss: 0.3649 - val_accuracy: 0.8791
# Epoch 4/20
# 54/54 [==============================] - 25s 457ms/step - loss: 0.2155 - accuracy: 0.9199 - val_loss: 0.1809 - val_accuracy: 0.9209
# Epoch 5/20
# 54/54 [==============================] - 26s 479ms/step - loss: 0.1941 - accuracy: 0.9187 - val_loss: 0.2429 - val_accuracy: 0.9140
# Epoch 6/20
# 54/54 [==============================] - 28s 510ms/step - loss: 0.1493 - accuracy: 0.9477 - val_loss: 0.2636 - val_accuracy: 0.9140
# Epoch 7/20
# 54/54 [==============================] - 24s 452ms/step - loss: 0.1016 - accuracy: 0.9646 - val_loss: 0.2581 - val_accuracy: 0.9233
# Epoch 8/20
# 54/54 [==============================] - 24s 450ms/step - loss: 0.1786 - accuracy: 0.9361 - val_loss: 0.1764 - val_accuracy: 0.9326
# Epoch 9/20
# 54/54 [==============================] - 24s 451ms/step - loss: 0.1292 - accuracy: 0.9553 - val_loss: 0.1290 - val_accuracy: 0.9488
# Epoch 10/20
# 54/54 [==============================] - 25s 462ms/step - loss: 0.0989 - accuracy: 0.9640 - val_loss: 0.1591 - val_accuracy: 0.9395
# Epoch 11/20
# 54/54 [==============================] - 24s 449ms/step - loss: 0.0833 - accuracy: 0.9686 - val_loss: 0.1441 - val_accuracy: 0.9488
# Epoch 12/20
# 54/54 [==============================] - 24s 452ms/step - loss: 0.0742 - accuracy: 0.9710 - val_loss: 0.2017 - val_accuracy: 0.9233
# Epoch 13/20
# 54/54 [==============================] - 25s 462ms/step - loss: 0.0809 - accuracy: 0.9704 - val_loss: 0.1100 - val_accuracy: 0.9605
# Epoch 14/20
# 54/54 [==============================] - 25s 459ms/step - loss: 0.0568 - accuracy: 0.9791 - val_loss: 0.1034 - val_accuracy: 0.9698
# Epoch 15/20
# 54/54 [==============================] - 24s 453ms/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 0.1021 - val_accuracy: 0.9721
# Epoch 16/20
# 54/54 [==============================] - 25s 465ms/step - loss: 0.0314 - accuracy: 0.9901 - val_loss: 0.0958 - val_accuracy: 0.9721
# Epoch 17/20
# 54/54 [==============================] - 25s 457ms/step - loss: 0.0447 - accuracy: 0.9866 - val_loss: 0.1526 - val_accuracy: 0.9395
# Epoch 18/20
# 54/54 [==============================] - 25s 465ms/step - loss: 0.0339 - accuracy: 0.9878 - val_loss: 0.2228 - val_accuracy: 0.9326
# Epoch 19/20
# 54/54 [==============================] - 25s 460ms/step - loss: 0.0308 - accuracy: 0.9884 - val_loss: 0.1309 - val_accuracy: 0.9605
# Epoch 20/20
# 54/54 [==============================] - 25s 461ms/step - loss: 0.0226 - accuracy: 0.9930 - val_loss: 0.1123 - val_accuracy: 0.9674

# %% [markdown]
# # Model Evaluation

# %%
train_loss = history.history['loss']

train_acc = history.history['accuracy']

valid_loss = history.history['val_loss']

valid_acc = history.history['val_accuracy']


# Accuracy plots

plt.figure(figsize=(8, 4))

plt.plot(train_acc, color='green', linestyle='-', label='train accuracy')

plt.plot(valid_acc, color='blue', linestyle='-', label='val accuracy')

plt.xlabel('Epochs')

plt.ylabel('Accuracy')

plt.legend()

plt.show()


# loss plots

plt.figure(figsize=(8, 4))

plt.plot(train_loss, color='orange', linestyle='-', label='train loss')

plt.plot(valid_loss, color='red', linestyle='-', label='val loss')

plt.xlabel('Epochs')

plt.ylabel('Loss')

plt.legend()

plt.show()

# %%
loss, acc = model.evaluate(val_ds, batch_size=batch_size)

print("validation accuracy :", round(acc, 2))

print("validation loss :", round(loss, 2))
# Out:
# 14/14 [==============================] - 2s 120ms/step - loss: 0.1123 - accuracy: 0.9674
# validation accuracy : 0.97
# validation loss : 0.11

# %%
y_pred = []  # store predicted labels

y_true = []  # store true labels


# iterate over the dataset

for image_batch, label_batch in val_ds:   # use dataset.unbatch() with repeat
    # append true labels
    y_true.append(label_batch)
    # compute predictions
    preds = model.predict(image_batch)
    # append predicted labels
    y_pred.append(np.argmax(preds, axis=- 1))


# convert the true and predicted labels into tensors

correct_labels = tf.concat([item for item in y_true], axis=0)

predicted_labels = tf.concat([item for item in y_pred], axis=0)

# %%
cm = confusion_matrix(correct_labels, predicted_labels, normalize='true')

sns.heatmap(cm, annot=True, cmap='viridis', cbar=None)

plt.title("Confusion matrix", fontweight='bold')

plt.ylabel("True", fontsize=14)

plt.xlabel("Predicted", fontsize=14)

plt.show()

# %%
print(classification_report(correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       204
#            1       0.93      0.87      0.90        31
#            2       0.95      0.97      0.96       195
#
#     accuracy                           0.97       430
#    macro avg       0.96      0.94      0.95       430
# weighted avg       0.97      0.97      0.97       430

# %% [markdown]
# # Post Processing

# %%
# Save
model.save("../application/static/models/model_v1.h5")

# %%
def prediction(img):
    class_names = ['Early_blight', 'Healthy', 'Late_blight']

    my_image = load_img(img, target_size=(img_height, img_width))
    my_image = img_to_array(my_image)
    my_image = np.expand_dims(my_image, 0)

    out = np.round(model.predict(my_image)[0], 2)
    fig = plt.figure(figsize=(7, 4))
    plt.barh(class_names, out, color='red ',
             edgecolor='red', linewidth=1, height=0.5)

    for index, value in enumerate(out):
        plt.text(value/2 + 0.1, index, f"{100*value:.2f}%", fontweight='bold')

    plt.xticks([])
    plt.yticks([0, 1, 2], labels=class_names, fontweight='bold', fontsize=14)
    fig.savefig('pred_img.png', bbox_inches='tight')
    return plt.show()

# %%
# Prediction on single Image
img = '../data/Healthy/04481ca2-f94c-457e-b785-1ac05800b7ec___RS_HL 1930.JPG'
prediction(img)

# %%
# Prediction on single Image
img = '../data/Early_blight/0182e991-97f0-4805-a1f7-6e1b4306d518___RS_Early.B 7015.JPG'
prediction(img)

# %%
# Prediction on single Image
img = '../data/Late_blight/01270f5c-a44b-4da7-9398-289088c197ab___RS_LB 2517.JPG'
prediction(img)

# %%
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array

print(tf.__version__)

############ settings ############
data_dir = r"data"

batch_size = 32
img_height = 128
img_width = 128
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)


def plot_distribution(y, title):
    a = Counter(y)
    y = ['Early_blight', 'Healthy', 'Late_blight']

    x = [a[i] for i in range(3)]
    plt.figure(figsize=(8, 3))
    plt.barh(y, x, color='blue')
    plt.title(title)
    return plt.show()


y_train = np.concatenate([y for x, y in train_ds], axis=0)
y_val = np.concatenate([y for x, y in val_ds], axis=0)

plot_distribution(y_train, title="Train images")
plot_distribution(y_val, title="Validation images")

# Sample images
class_names = train_ds.class_names

for class_name in class_names:
    imgs = os.listdir(os.path.join(data_dir, class_name))[:3]
    plt.figure(figsize=(10, 10))
    for i, img in enumerate(imgs):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(plt.imread(os.path.join(data_dir, class_name, img)))
        plt.title(class_name)
        plt.axis('off')

# Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Model architecture - ResNet-101
num_classes = 3

# Create ResNet-101 model with pre-trained ImageNet weights
base_model = tf.keras.applications.ResNet101(
    weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Freeze the layers of the pre-trained model
base_model.trainable = False

# Build the custom model on top of ResNet-101
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Early stopping callback
earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                                      min_delta=0.0001,
                                                      patience=5)

# Train the model
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=20,
                    callbacks=[earlystop_callback])

# Plot accuracy and loss
train_loss = history.history['loss']
train_acc = history.history['accuracy']
valid_loss = history.history['val_loss']
valid_acc = history.history['val_accuracy']

# Accuracy plots
plt.figure(figsize=(8, 4))
plt.plot(train_acc, color='green', linestyle='-', label='train accuracy')
plt.plot(valid_acc, color='blue', linestyle='-', label='val accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss plots
plt.figure(figsize=(8, 4))
plt.plot(train_loss, color='orange', linestyle='-', label='train loss')
plt.plot(valid_loss, color='red', linestyle='-', label='val loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluate the model
loss, acc = model.evaluate(val_ds, batch_size=batch_size)
print("Validation accuracy:", round(acc, 2))
print("Validation loss:", round(loss, 2))

# Confusion matrix
y_pred = []  # store predicted labels
y_true = []  # store true labels

# Iterate over the dataset
for image_batch, label_batch in val_ds:
    # Append true labels
    y_true.append(label_batch)
    # Compute predictions
    preds = model.predict(image_batch)
    # Append predicted labels
    y_pred.append(np.argmax(preds, axis=-1))

# Convert the true and predicted labels into tensors
correct_labels = tf.concat([item for item in y_true], axis=0)
predicted_labels = tf.concat([item for item in y_pred], axis=0)
cm = confusion_matrix(correct_labels, predicted_labels, normalize='true')

# Plot the confusion matrix
sns.heatmap(cm, annot=True, cmap='viridis', cbar=None)
plt.title("Confusion matrix", fontweight='bold')
plt.ylabel("True", fontsize=14)
plt.xlabel("Predicted", fontsize=14)
plt.show()
# Out:
# 2.15.0
# Found 2152 files belonging to 3 classes.
# Using 1722 files for training.
# Found 2152 files belonging to 3 classes.
# Using 430 files for validation.
# WARNING:tensorflow:From C:\Users\Home\AppData\Roaming\Python\Python310\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Home\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\Home\AppData\Roaming\Python\Python310\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\Home\AppData\Roaming\Python\Python310\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Home\AppData\Roaming\Python\Python310\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 54/54 [==============================] - 120s 2s/step - loss: 0.4772 - accuracy: 0.8484 - val_loss: 0.1641 - val_accuracy: 0.9372
# Epoch 2/20
# 54/54 [==============================] - 136s 3s/step - loss: 0.1410 - accuracy: 0.9472 - val_loss: 0.1138 - val_accuracy: 0.9535
# Epoch 3/20
# 54/54 [==============================] - 180s 3s/step - loss: 0.1157 - accuracy: 0.9570 - val_loss: 0.0926 - val_accuracy: 0.9628
# Epoch 4/20
# 54/54 [==============================] - 150s 3s/step - loss: 0.0908 - accuracy: 0.9640 - val_loss: 0.1145 - val_accuracy: 0.9535
# Epoch 5/20
# 54/54 [==============================] - 156s 3s/step - loss: 0.0798 - accuracy: 0.9704 - val_loss: 0.1035 - val_accuracy: 0.9535
# Epoch 6/20
# 54/54 [==============================] - 161s 3s/step - loss: 0.0619 - accuracy: 0.9814 - val_loss: 0.0921 - val_accuracy: 0.9651
# Epoch 7/20
# 54/54 [==============================] - 166s 3s/step - loss: 0.0428 - accuracy: 0.9832 - val_loss: 0.0860 - val_accuracy: 0.9674
# Epoch 8/20
# 54/54 [==============================] - 152s 3s/step - loss: 0.0398 - accuracy: 0.9872 - val_loss: 0.0651 - val_accuracy: 0.9698
# Epoch 9/20
# 54/54 [==============================] - 167s 3s/step - loss: 0.0328 - accuracy: 0.9890 - val_loss: 0.0586 - val_accuracy: 0.9744
# Epoch 10/20
# 54/54 [==============================] - 168s 3s/step - loss: 0.0290 - accuracy: 0.9890 - val_loss: 0.0512 - val_accuracy: 0.9791
# Epoch 11/20
# 54/54 [==============================] - 140s 3s/step - loss: 0.0250 - accuracy: 0.9901 - val_loss: 0.0654 - val_accuracy: 0.9744
# Epoch 12/20
# 54/54 [==============================] - 168s 3s/step - loss: 0.0233 - accuracy: 0.9925 - val_loss: 0.0879 - val_accuracy: 0.9605
# Epoch 13/20
# 54/54 [==============================] - 166s 3s/step - loss: 0.0306 - accuracy: 0.9895 - val_loss: 0.0726 - val_accuracy: 0.9674
# Epoch 14/20
# 54/54 [==============================] - 167s 3s/step - loss: 0.0237 - accuracy: 0.9907 - val_loss: 0.0533 - val_accuracy: 0.9791
# Epoch 15/20
# 54/54 [==============================] - 159s 3s/step - loss: 0.0187 - accuracy: 0.9948 - val_loss: 0.0688 - val_accuracy: 0.9721
# 14/14 [==============================] - 32s 2s/step - loss: 0.0688 - accuracy: 0.9721
# Validation accuracy: 0.97
# Validation loss: 0.07
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 5s 5s/step

# %%
# Save the model
model.save("resnet101_model.h5")
# Out:
# C:\Users\Home\AppData\Roaming\Python\Python310\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
def prediction(img):
    class_names = ['Early_blight', 'Healthy', 'Late_blight']

    my_image = load_img(img, target_size=(img_height, img_width))
    my_image = img_to_array(my_image)
    my_image = np.expand_dims(my_image, 0)

    out = np.round(model.predict(my_image)[0], 2)
    fig = plt.figure(figsize=(7, 4))
    plt.barh(class_names, out, color='red',
             edgecolor='red', linewidth=1, height=0.5)

    for index, value in enumerate(out):
        plt.text(value/2 + 0.1, index, f"{100*value:.2f}%", fontweight='bold')

    plt.xticks([])
    plt.yticks([0, 1, 2], labels=class_names, fontweight='bold', fontsize=14)
    fig.savefig('pred_img.png', bbox_inches='tight')
    return plt.show()

# %%
img = '0a47f32c-1724-4c8d-bfe4-986cedd3587b___RS_Early.B 8001.JPG'
prediction(img)
# Out:
# 1/1 [==============================] - 0s 154ms/step
